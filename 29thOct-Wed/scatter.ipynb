# %%
import matplotlib.pyplot as plt

# %%
car=[5,10,21,4,3,53,54,32]
speed=[90,78,56,32,110,140,150,160]

# %%
plt.scatter(car,speed)
plt.show()

# %%
import numpy as np
ag=np.random.normal(0.0,5.0,250)
ga=np.random.normal(5.0,20.0,250)

plt.scatter(ag,ga)
plt.show()

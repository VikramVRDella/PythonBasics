# %%
import numpy as np

x=np.random.uniform(0.0,50.0,250)

print(x)
# Out:
# [3.20580304e+01 4.17228493e+01 3.10995653e+01 2.07789506e+00
#  3.68816438e+01 2.58642920e+01 8.55982890e-01 3.08937976e+00
#  3.82101557e+01 1.90421780e+01 1.49537426e+01 2.37424247e+01
#  2.65161951e+01 4.46970751e+01 2.43672466e+01 6.41401457e+00
#  1.85989898e+01 2.29997830e+01 6.59344853e+00 1.58132642e+01
#  3.22584677e+01 2.55513687e+01 2.90140762e-01 2.97203764e-01
#  2.20669970e+01 2.00721531e+01 1.73839389e+01 1.39833646e+01
#  4.84360364e+01 4.03906838e+01 1.88214045e+01 3.63491832e+01
#  4.65829462e+01 1.22100320e+01 4.63248438e+01 1.22169592e+01
#  3.07404248e+01 3.02374779e+01 7.81301283e+00 9.59976597e+00
#  3.08198432e+01 3.18326940e+00 3.16552708e+01 3.56768190e+01
#  1.25225570e+01 1.66068485e+01 3.30037671e+01 1.77857106e+01
#  3.67138053e+01 1.94545946e+01 2.99749230e+01 2.99417554e+01
#  6.58802951e+00 2.87273283e+01 2.08971347e+01 3.40392218e+01
#  1.85606936e+01 5.51926226e+00 7.49128037e+00 8.31005651e+00
# ...

# %%
import matplotlib.pyplot as plt

plt.hist(x,5)
plt.show()

# %%
y=np.random.uniform(0.0,5.0,10000)
plt.hist(y,100)
plt.show()

# %%
z=np.random.normal(0.0,0.5,10000)
plt.hist(z,100)
plt.show()

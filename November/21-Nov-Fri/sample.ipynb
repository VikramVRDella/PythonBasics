# %%
pip install matplotlib
# Out:
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...
#   Using cached pyparsing-3.2.5-py3-none-any.whl.metadata (5.0 kB)
# ...
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    - -------------------------------------- 0.3/8.1 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/8.1 MB 1.1 MB/s eta 0:00:07
#    --- ------------------------------------ 0.8/8.1 MB 1.2 MB/s eta 0:00:07
#    --- ------------------------------------ 0.8/8.1 MB 1.2 MB/s eta 0:00:07
#    ----- ---------------------------------- 1.0/8.1 MB 986.7 kB/s eta 0:00:08
#    ----- ---------------------------------- 1.0/8.1 MB 986.7 kB/s eta 0:00:08
#    ----- ---------------------------------- 1.0/8.1 MB 986.7 kB/s eta 0:00:08
#    ------ --------------------------------- 1.3/8.1 MB 664.1 kB/s eta 0:00:11
#    ------ --------------------------------- 1.3/8.1 MB 664.1 kB/s eta 0:00:11
# ...

# %%
import matplotlib.pyplot as plt

# %%
x=[i for i in range(5)]
print(x)
y=[j for j in range(6,11)]
print(y)
# Out:
# [0, 1, 2, 3, 4]
# [6, 7, 8, 9, 10]

# %%
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.plot(x,y)

# %%
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.scatter(x,y)
